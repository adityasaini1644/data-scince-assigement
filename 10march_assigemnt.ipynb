# %% [markdown]
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %% [markdown]
# Estimation statistics is a branch of statistics that deals with estimating or predicting population parameters from sample statistics. Point estimate is a single value that is used to estimate an unknown population parameter. For example, the sample mean is often used as a point estimate of the population mean. Interval estimate, on the other hand, is an estimate of the range of values that the population parameter is likely to fall within. For example, a confidence interval is an interval estimate of the population mean.

# %% [markdown]
# Q2. Write a Python function to estimate the population mean using a sample mean and standard
# deviation.

# %%
def estimate_pop_mean(sample_mean, sample_std, sample_size):
    import math
    z_score = 1.96 # for 95% confidence interval
    margin_error = z_score * sample_std / math.sqrt(sample_size)
    lower_bound = sample_mean - margin_error
    upper_bound = sample_mean + margin_error
    return (lower_bound, upper_bound)

# %% [markdown]
# Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %% [markdown]
# Hypothesis testing is a statistical method used to determine whether an assumption or claim about a population parameter is supported by the evidence provided by a sample. It involves formulating a null hypothesis, which assumes that there is no difference between the sample and the population, and an alternative hypothesis, which states that there is a difference between the sample and the population. The null hypothesis is then tested using a statistical test, and if the test results are significant, the null hypothesis is rejected in favor of the alternative hypothesis.
#
# Hypothesis testing is important because it provides a way to make inferences about a population based on a sample, and to determine the reliability of these inferences. It is widely used in scientific research, business, and other fields to test theories, evaluate the effectiveness of treatments or interventions, and make decisions based on data.

# %% [markdown]
# Q4. Create a hypothesis that states whether the average weight of male college students is greater than
# the average weight of female college students.

# %% [markdown]
# Null hypothesis: The average weight of male college students is equal to or less than the average weight of female college students.
#
# Alternative hypothesis: The average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# Q5. Write a Python script to conduct a hypothesis test on the difference between two population means,
# given a sample from each population.

# %%
import numpy as np
from scipy import stats

# sample data
sample1 = [23, 25, 29, 30, 32]
sample2 = [19, 22, 26, 28, 30]

# conduct two-sample t-test
t_stat, p_val = stats.ttest_ind(sample1, sample2)

# print results
print("t-statistic: ", t_stat)
print("p-value: ", p_val)
# Out:
# t-statistic:  1.0785197020798836
# p-value:  0.31224394009642664

# %% [markdown]
# Q6: What is a null and alternative hypothesis? Give some examples.

# %% [markdown]
# A null hypothesis is a statement that assumes there is no significant difference or relationship between two or more variables, while an alternative hypothesis is a statement that assumes there is a significant difference or relationship between two or more variables.
#
# Examples of null and alternative hypotheses:
#
# Null hypothesis: The mean height of male and female students is the same. Alternative hypothesis: The mean height of male students is greater than the mean height of female students.
# Null hypothesis: There is no significant difference in sales between two stores. Alternative hypothesis: Store A has higher sales than Store B.
# Null hypothesis: The new drug has no effect on blood pressure. Alternative hypothesis: The new drug lowers blood pressure significantly more than the placebo.

# %% [markdown]
# Q7: Write down the steps involved in hypothesis testing.

# %% [markdown]
# State the null hypothesis and alternative hypothesis.
# Choose the appropriate test statistic and level of significance.
# Collect the sample data and calculate the test statistic.
# Determine the p-value associated with the test statistic.
# Compare the p-value with the level of significance and make a decision.
# Interpret the results and draw a conclusion

# %% [markdown]
# Q8. Define p-value and explain its significance in hypothesis testing.

# %% [markdown]
# p-value is the probability of observing a test statistic as extreme as or more extreme than the one calculated from the sample data, assuming the null hypothesis is true. It is used in hypothesis testing to determine the significance of the test statistic. A small p-value (less than the level of significance) indicates that the null hypothesis can be rejected in favor of the alternative hypothesis.

# %% [markdown]
# Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom
# parameter set to 10.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import t

df = 10  # degrees of freedom
x = np.linspace(-5, 5, 1000)  # range of values
y = t.pdf(x, df)  # t-distribution values

plt.plot(x, y)
plt.title('Student\'s t-Distribution with df=10')
plt.xlabel('x')
plt.ylabel('PDF(x)')
plt.show()

# %% [markdown]
# Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two
# random samples of equal size and a null hypothesis that the population means are equal.

# %%
import scipy.stats as stats

# sample data
sample1 = [1, 2, 3, 4, 5]
sample2 = [2, 3, 4, 5, 6]

# calculate t-statistic and p-value
t_stat, p_val = stats.ttest_ind(sample1, sample2)

print('t-statistic:', t_stat)
print('p-value:', p_val)
# Out:
# t-statistic: -1.0
# p-value: 0.34659350708733416

# %% [markdown]
# Q11: What is Student’s t distribution? When to use the t-Distribution.

# %% [markdown]
# Student's t-distribution is a probability distribution used in statistical inference for small sample sizes, when the population standard deviation is unknown. It is a bell-shaped distribution, similar to the standard normal distribution, but with heavier tails. It is used when the sample size is small (less than 30) or when the population standard deviation is unknown.

# %% [markdown]
# Q12: What is t-statistic? State the formula for t-statistic.

# %% [markdown]
# t-statistic is a test statistic used in hypothesis testing when the population standard deviation is unknown. It measures how many standard errors the sample mean is from the hypothesized population mean. The formula for t-statistic is:
#
# t = (x̄ - μ) / (s / sqrt(n))
#
# where x̄ is the sample mean, μ is the hypothesized population mean, s is the sample standard deviation, and n is the sample size.

# %% [markdown]
# Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
# sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50.
# Estimate the population mean revenue with a 95% confidence interval.

# %%
import scipy.stats as stats

n = 50
sample_mean = 500
sample_std = 50
conf_level = 0.95

# calculate the margin of error
z_critical = stats.norm.ppf((1 - conf_level) / 2)
margin_of_error = z_critical * (sample_std / np.sqrt(n))

# calculate the confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print('95% confidence interval:', (lower_bound, upper_bound))
# Out:
# 95% confidence interval: (513.8590382434968, 486.1409617565032)

# %% [markdown]
# Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a
# clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a
# standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %% [markdown]
# To test the hypothesis that the new drug will decrease blood pressure by 10 mmHg with a significance level of 0.05, we can perform a one-sample t-test with the null hypothesis being that the true mean decrease in blood pressure is not 10 mmHg.
#
# The test statistic is calculated as:
#
# t = (sample mean - hypothesized mean) / (standard deviation / sqrt(sample size))
# t = (8 - 10) / (3 / sqrt(100))
# t = -4.47
#
# The degrees of freedom for this test is (sample size - 1) = 99. Using a t-table or calculator, we find the p-value to be less than 0.0001. This means that the probability of obtaining a sample mean of 8 or lower if the true mean is 10 is very small.
#
# Since the p-value is less than the significance level of 0.05, we reject the null hypothesis and conclude that the new drug does decrease blood pressure by more than 10 mmHg.

# %% [markdown]
# Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a
# standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight
# is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5
# pounds with a significance level of 0.01.

# %% [markdown]
# To test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01, we can perform a one-sample t-test with the null hypothesis being that the true mean weight is 5 pounds.
#
# The test statistic is calculated as:
#
# t = (sample mean - hypothesized mean) / (standard deviation / sqrt(sample size))
# t = (4.8 - 5) / (0.5 / sqrt(25))
# t = -2
#
# The degrees of freedom for this test is (sample size - 1) = 24. Using a t-table or calculator, we find the p-value to be 0.0287. This means that the probability of obtaining a sample mean of 4.8 or lower if the true mean is 5 is 0.0287.
#
# Since the p-value is less than the significance level of 0.01, we reject the null hypothesis and conclude that the true mean weight of the products is less than 5 pounds.

# %% [markdown]
# Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 =
# 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
# score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
# groups are equal with a significance level of 0.01.

# %% [markdown]
#  To test the hypothesis that the population means for the two groups are equal with a significance level of 0.01, we can perform a two-sample t-test with the null hypothesis being that the difference between the means is 0.
#
# The test statistic is calculated as:
#
# t = (sample mean difference - hypothesized mean difference) / (standard error of the difference)
# standard error of the difference = sqrt((s1^2/n1) + (s2^2/n2))
# t = (80 - 75) / sqrt((10^2/30) + (8^2/40))
# t = 3.05
#
# The degrees of freedom for this test is (n1 + n2 - 2) = 68. Using a t-table or calculator, we find the two-tailed p-value to be 0.0033. This means that the probability of obtaining a sample mean difference of 5 or more (in either direction) if the true mean difference is 0 is 0.0033.
#
# Since the p-value is less than the significance level of 0.01, we reject the null hypothesis and conclude that the population means for the two groups are not equal.

# %% [markdown]
# Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV
# program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard
# deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %% [markdown]
#  To estimate the population mean with a 99% confidence interval, we can use the formula:
#
# confidence interval = sample mean ± (z-score * standard error)
# standard error = standard deviation / sqrt(sample size)
# z-score for 99% confidence level = 2.576
#
# Substituting the given values, we get:
#
# confidence interval = 4 ± (2.576 * 1.5 / sqrt(50))
